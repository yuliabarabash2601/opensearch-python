# %% [markdown]
# #### How to search in OpenSearch

# %% [markdown]
# ### 1. Import Libraries:

# %%
import pandas as pd
from opensearchpy import OpenSearch
from opensearchpy.client.indices import IndicesClient
import json

# %% [markdown]
# ### 2. Create Client OpenSearch

# %%
opensearch_client =OpenSearch(
    hosts = [{"host": "localhost", "port": 9200}],
    http_auth = ("admin", "admin"),
    use_ssl = True,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
)

# %% [markdown]
# ### 3. Define Mapping for an index.

# %%
index_mapping = {
  "mappings": {
    "properties": {
      "genres": {
        "type": "keyword"
      },
        "title": {
        "type": "text"
        }
    }
  }
}

# %% [markdown]
# For our demo purpose we will use the NintendoGames dataset. The dataset contains 9 columns. However, we will only use the title and genres columns for our demo. We will define the genres column as a keyword and the title column as a text.

# %% [markdown]
# ### 4. Create an index

# %%
opensearch_client.indices.create(index='nintendo_games', body=index_mapping)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'nintendo_games'}

# %% [markdown]
# ### 5. Check if the index was created

# %%
opensearch_client.indices.exists(index='nintendo_games')
# Out:
# True

# %%
opensearch_client.indices.delete(index='nintendo_games')
# Out:
# {'acknowledged': True}

# %% [markdown]
# ### 6. Load the dataset and transform it to json

# %%
dataset = pd.read_csv('NintendoGames.csv')

# %%
dataset['genres'] = dataset['genres'].transform(lambda x: x.strip('[]').replace("'", "").split(', '))

# %%
dataset = json.loads(dataset.to_json(orient='records'))

# %%
dataset[0]
# Out:
# {'meta_score': None,
#  'title': 'Super Mario RPG',
#  'platform': 'Switch',
#  'date': 'Nov 17, 2023',
#  'user_score': None,
#  'link': '/game/switch/super-mario-rpg',
#  'esrb_rating': 'E',
#  'developers': "['Nintendo']",
#  'genres': ['Role-Playing', 'Japanese-Style']}

# %% [markdown]
# ### 7. Create a bulk operation

# %% [markdown]
# During Bulk operation, it is possible to do multiple operations in a single request such as:
# * create - to create a document if it doesn’t already exist and returns an error otherwise
# * delete - to delete a document
# * index - to create a document if it doesn’t already exist and returns an error otherwise
# * update - to update existing documents and returns an error if the document doesn’t exist
#
# In our case, we will create a bulk operation to index all the documents in the dataset by using index operation.

# %%
def create_bulk_opensearch(index_name, dataset):
    bulk_opensearch = ''
    for row in dataset:
        bulk_opensearch += '{"index": {"_index": "%s"}}\n' % index_name
        bulk_opensearch += json.dumps(row) + '\n'
    return bulk_opensearch

bulk_opensearch = create_bulk_opensearch('nintendo_games', dataset)

# %% [markdown]
# after transforming dataset for preparing bulk operation, we will get the following result:

# %%
bulk_opensearch
# Out:
# '{"index": {"_index": "nintendo_games"}}\n{"meta_score": null, "title": "Super Mario RPG", "platform": "Switch", "date": "Nov 17, 2023", "user_score": null, "link": "/game/switch/super-mario-rpg", "esrb_rating": "E", "developers": "[\'Nintendo\']", "genres": ["Role-Playing", "Japanese-Style"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score": null, "title": "WarioWare: Move It!", "platform": "Switch", "date": "Nov 3, 2023", "user_score": null, "link": "/game/switch/warioware-move-it!", "esrb_rating": "RP", "developers": "[\'Intelligent Systems\']", "genres": ["Miscellaneous", "Party / Minigame"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score": null, "title": "Super Mario Bros. Wonder", "platform": "Switch", "date": "Oct 20, 2023", "user_score": null, "link": "/game/switch/super-mario-bros-wonder", "esrb_rating": "E", "developers": "[\'Nintendo\']", "genres": ["Action", "Platformer", "2D"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score": null, "title": "Detective Pikachu Returns", "platform": "Switch", "date": "Oct 6, 2023", "user_score": null, "link": "/game/switch/detective-pikachu-returns", "esrb_rating": null, "developers": "[\'Creatures Inc.\']", "genres": ["Adventure", "3D", "Third-Person"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score": null, "title": "Fae Farm", "platform": "Switch", "date": "Sep 8, 2023", "user_score": null, "link": "/game/switch/fae-farm", "esrb_rating": "E10+", "developers": "[\'Phoenix Labs\']", "genres": ["Simulation", "Virtual", "Virtual Life"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score": 87.0, "title": "Pikmin 4", "platform": "Switch", "date": "Jul 21, 2023", "user_score": 9.0, "link": "/game/switch/pikmin-4", "esrb_rating": "E10+", "developers": "[\'Nintendo\']", "genres": ["Strategy", "Real-Time", "General"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score": null, "title": "Pokemon Sleep", "platform": "iOS", "date": "Jul 20, 2023", "user_score": null, "link": "/game/ios/pokemon-sleep", "esrb_rating": null, "developers": "[\'The Pokemon Company\', \' Select Button\']", "genres": ["Role-Playing", "Miscellaneous", "Application", "Trainer"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score": 74.0, "title": "Mario Kart 8 Deluxe: Booster Course Pass - Wave 5", "platform": "Switch", "date": "Jul 12, 2023", "user_score": 7.6, "link": "/game/switch/mario-kart-8-deluxe-booster-course-pass---wave-5", "esrb_rating": null, "developers": "[\'Nintendo\']", "genres": ["Racing", "Arcade", "Automobile"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score": 56.0, "title": "Everybody 1-2-Switch!", "platform": "Switch", "date": "Jun 30, 2023", "user_score": 5.4, "link": "/game/switch/everybody-1-2-switch!", "esrb_rating": "E", "developers": "[\'Nintendo\']", "genres": ["Miscellaneous", "Party / Minigame"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score": 82.0, "title": "Pikmin 1", "platform": "Switch", "date": "Jun 21, 2023", "user_score": 8.4, "link": "/game/switch/pikmin-1", "esrb_rating": "E10+", "developers": "[\'Nintendo\']", "genres": ["Strategy", "Real-Time", "General"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score": 65.0, "title": "Pikmin 2", "platform": "Switch", "date": "Jun 21, 2023", "user_score": 8.6, "link": "/game/switch/pikmin-2", "esrb_rating": "E10+", "developers": "[\'Nintendo\']", "genres": ["Strategy", "Real-Time", "General"]}\n{"index": {"_index": "nintendo_games"}}\n{"meta_score":

#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2081,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '08PlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2082,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '1MPlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2083,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '1cPlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2084,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '1sPlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2085,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '18PlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2086,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '2MPlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2087,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '2cPlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2088,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '2sPlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2089,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '28PlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2090,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '3MPlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2091,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '3cPlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2092,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'nintendo_games',
#     '_id': '3sPlZIoBqjgNgJpQ8cbQ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2093,
#     '_primary_term': 1,
#     'status': 201}},
#   ...]}

# %% [markdown]
# Check if there are any errors

# %%
response_bulk['errors']
# Out:
# False

# %%
index_mapping =  IndicesClient(opensearch_client).get_mapping(index='nintendo_games')

# %%
index_mapping
# Out:
# {'nintendo_games': {'mappings': {'properties': {'date': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'developers': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'esrb_rating': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'genres': {'type': 'keyword'},
#     'link': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'meta_score': {'type': 'float'},
#     'platform': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'title': {'type': 'text'},
#     'user_score': {'type': 'float'}}}}}

# %%
title_mapping = index_mapping['nintendo_games']['mappings']['properties']['title']

# %%
title_mapping
# Out:
# {'type': 'text'}

# %% [markdown]
# Full Text Search

# %%
search_1 = opensearch_client.search(body={
    "query": {
        "match": {
            "title": "Mario"
        }
    }
})

# %%
search_1
# Out:
# {'took': 107,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 302, 'relation': 'eq'},
#   'max_score': 2.5115013,
#   'hits': [{'_index': 'nintendo_games',
#     '_id': '5Dq4XIoBTw-2vdEqo5HK',
#     '_score': 2.5115013,
#     '_source': {'meta_score': None,
#      'title': 'Mario Tennis',
#      'platform': 'WII',
#      'date': 'Jun 28, 2010',
#      'user_score': None,
#      'link': '/game/wii/mario-tennis',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': "['Sports', 'Traditional', 'Tennis']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'STq4XIoBTw-2vdEqo5LK',
#     '_score': 2.5115013,
#     '_source': {'meta_score': None,
#      'title': 'Mario Calculator',
#      'platform': 'DS',
#      'date': 'Jun 15, 2009',
#      'user_score': 6.3,
#      'link': '/game/ds/mario-calculator',
#      'esrb_rating': None,
#      'developers': "['Nintendo']",
#      'genres': "['Action', 'Miscellaneous', 'General', 'Edutainment']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'Sjq4XIoBTw-2vdEqo5LK',
#     '_score': 2.5115013,
#     '_source': {'meta_score': None,
#      'title': 'Mario Clock',
#      'platform': 'DS',
#      'date': 'Jun 15, 2009',
#      'user_score': 6.0,
#      'link': '/game/ds/mario-clock',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': "['Miscellaneous', 'General', 'General', 'Application']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'dTq4XIoBTw-2vdEqo5LK',
#     '_score': 2.5115013,
#     '_source': {'meta_score': None,
#      'title': 'Mario Golf',
#      'platform': 'WII',
#      'date': 'Oct 6, 2008',
#      'user_score': None,
#      'link': '/game/wii/mario-golf',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': "['Sports', 'Traditional', 'Golf', 'Arcade']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'szq4XIoBTw-2vdEqo5LL',
#     '_score': 2.5115013,
#     '_source': {'meta_score': None,
#      'title': 'Paper Mario',
#      'platform': 'WII',
#      'date': 'Jul 16, 2007',
#      'user_score': 8.7,
#      'link': '/game/wii/paper-mario',
#      'esrb_rating': 'E',
#      'developers': "['Intelligent Systems']",
#      'genres': "['Role-Playing', 'Console-style RPG']"}},
#    {'_index': 'nintendo_games',
#     '_id': '-Tq4XIoBTw-2vdEqo5LL',
#     '_score': 2.5115013,
#     '_source': {'meta_score': None,
#      'title': 'Mario Bros.',
#      'platform': 'WII',
#      'date': 'Nov 19, 2006',
#      'user_score': 6.6,
#      'link': '/game/wii/mario-bros',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': "['Action', 'Platformer', '2D']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'njq4XIoBTw-2vdEqo5PL',
#     '_score': 2.5115013,
#     '_source': {'meta_score': 93.0,
#      'title': 'Paper Mario',
#      'platform': 'N64',
#      'date': 'Feb 5, 2001',
#      'user_score': 9.0,
#      'link': '/game/nintendo-64/paper-mario',
#      'esrb_rating': 'E',
#      'developers': "['Intelligent Systems']",
#      'genres': "['Role-Playing', 'Console-style RPG']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'pDq4XIoBTw-2vdEqo5PL',
#     '_score': 2.5115013,
#     '_source': {'meta_score': 91.0,
#      'title': 'Mario Tennis',
#      'platform': 'N64',
#      'date': 'Aug 28, 2000',
#      'user_score': 8.7,
#      'link': '/game/nintendo-64/mario-tennis',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': "['Sports', 'Traditional', 'Tennis']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'qjq4XIoBTw-2vdEqo5PL',
#     '_score': 2.5115013,
#     '_source': {'meta_score': 91.0,
#      'title': 'Mario Golf',
#      'platform': 'N64',
#      'date': 'Jun 30, 1999',
#      'user_score': 7.8,
#      'link': '/game/nintendo-64/mario-golf',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': "['Sports', 'Traditional', 'Golf', 'Arcade']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'rTq4XIoBTw-2vdEqo5PL',
#     '_score': 2.5115013,
#     '_source': {'meta_score': 79.0,
#      'title': 'Mario Party',
#      'platform': 'N64',
#      'date': 'Feb 8, 1999',
#      'user_score': 8.0,
#      'link': '/game/nintendo-64/mario-party',
#      'esrb_rating': 'E',
#      'developers': "['Hudson']",
#      'genres': "['Miscellaneous', 'Party']"}}]}}

# %%
search_2 = opensearch_client.search(body={
    "query": {
        "match": {
            "title": {
                "query": "Maroi",
                "fuzziness": "AUTO"
            }
        }
    }
})

# %%
search_2
# Out:
# {'took': 18,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 302, 'relation': 'eq'},
#   'max_score': 2.009201,
#   'hits': [{'_index': 'nintendo_games',
#     '_id': '5Dq4XIoBTw-2vdEqo5HK',
#     '_score': 2.009201,
#     '_source': {'meta_score': None,
#      'title': 'Mario Tennis',
#      'platform': 'WII',
#      'date': 'Jun 28, 2010',
#      'user_score': None,
#      'link': '/game/wii/mario-tennis',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': "['Sports', 'Traditional', 'Tennis']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'STq4XIoBTw-2vdEqo5LK',
#     '_score': 2.009201,
#     '_source': {'meta_score': None,
#      'title': 'Mario Calculator',
#      'platform': 'DS',
#      'date': 'Jun 15, 2009',
#      'user_score': 6.3,
#      'link': '/game/ds/mario-calculator',
#      'esrb_rating': None,
#      'developers': "['Nintendo']",
#      'genres': "['Action', 'Miscellaneous', 'General', 'Edutainment']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'Sjq4XIoBTw-2vdEqo5LK',
#     '_score': 2.009201,
#     '_source': {'meta_score': None,
#      'title': 'Mario Clock',
#      'platform': 'DS',
#      'date': 'Jun 15, 2009',
#      'user_score': 6.0,
#      'link': '/game/ds/mario-clock',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': "['Miscellaneous', 'General', 'General', 'Application']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'dTq4XIoBTw-2vdEqo5LK',
#     '_score': 2.009201,
#     '_source': {'meta_score': None,
#      'title': 'Mario Golf',
#      'platform': 'WII',
#      'date': 'Oct 6, 2008',
#      'user_score': None,
#      'link': '/game/wii/mario-golf',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': "['Sports', 'Traditional', 'Golf', 'Arcade']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'szq4XIoBTw-2vdEqo5LL',
#     '_score': 2.009201,
#     '_source': {'meta_score': None,
#      'title': 'Paper Mario',
#      'platform': 'WII',
#      'date': 'Jul 16, 2007',
#      'user_score': 8.7,
#      'link': '/game/wii/paper-mario',
#      'esrb_rating': 'E',
#      'developers': "['Intelligent Systems']",
#      'genres': "['Role-Playing', 'Console-style RPG']"}},
#    {'_index': 'nintendo_games',
#     '_id': '-Tq4XIoBTw-2vdEqo5LL',
#     '_score': 2.009201,
#     '_source': {'meta_score': None,
#      'title': 'Mario Bros.',
#      'platform': 'WII',
#      'date': 'Nov 19, 2006',
#      'user_score': 6.6,
#      'link': '/game/wii/mario-bros',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': "['Action', 'Platformer', '2D']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'njq4XIoBTw-2vdEqo5PL',
#     '_score': 2.009201,
#     '_source': {'meta_score': 93.0,
#      'title': 'Paper Mario',
#      'platform': 'N64',
#      'date': 'Feb 5, 2001',
#      'user_score': 9.0,
#      'link': '/game/nintendo-64/paper-mario',
#      'esrb_rating': 'E',
#      'developers': "['Intelligent Systems']",
#      'genres': "['Role-Playing', 'Console-style RPG']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'pDq4XIoBTw-2vdEqo5PL',
#     '_score': 2.009201,
#     '_source': {'meta_score': 91.0,
#      'title': 'Mario Tennis',
#      'platform': 'N64',
#      'date': 'Aug 28, 2000',
#      'user_score': 8.7,
#      'link': '/game/nintendo-64/mario-tennis',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': "['Sports', 'Traditional', 'Tennis']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'qjq4XIoBTw-2vdEqo5PL',
#     '_score': 2.009201,
#     '_source': {'meta_score': 91.0,
#      'title': 'Mario Golf',
#      'platform': 'N64',
#      'date': 'Jun 30, 1999',
#      'user_score': 7.8,
#      'link': '/game/nintendo-64/mario-golf',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': "['Sports', 'Traditional', 'Golf', 'Arcade']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'rTq4XIoBTw-2vdEqo5PL',
#     '_score': 2.009201,
#     '_source': {'meta_score': 79.0,
#      'title': 'Mario Party',
#      'platform': 'N64',
#      'date': 'Feb 8, 1999',
#      'user_score': 8.0,
#      'link': '/game/nintendo-64/mario-party',
#      'esrb_rating': 'E',
#      'developers': "['Hudson']",
#      'genres': "['Miscellaneous', 'Party']"}}]}}

# %%
search_3 = opensearch_client.search(body={
    "query": {
        "multi_match": {
            "query": "*gent",
            "fields": ["title^2", "developers^1"],
            "fuzziness": "3"
        }
    }
})

# %%
search_3
# Out:
# {'took': 24,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 60, 'relation': 'eq'},
#   'max_score': 12.522595,
#   'hits': [{'_index': 'nintendo_games',
#     '_id': '_zq4XIoBTw-2vdEqo5LL',
#     '_score': 12.522595,
#     '_source': {'meta_score': 87.0,
#      'title': 'Elite Beat Agents',
#      'platform': 'DS',
#      'date': 'Nov 6, 2006',
#      'user_score': 8.5,
#      'link': '/game/ds/elite-beat-agents',
#      'esrb_rating': 'E10+',
#      'developers': "['iNiS']",
#      'genres': "['Action', 'Miscellaneous', 'Rhythm', 'Music', 'Music']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'STrCXIoBTw-2vdEq9Jeh',
#     '_score': 12.522595,
#     '_source': {'meta_score': 87.0,
#      'title': 'Elite Beat Agents',
#      'platform': 'DS',
#      'date': 'Nov 6, 2006',
#      'user_score': 8.5,
#      'link': '/game/ds/elite-beat-agents',
#      'esrb_rating': 'E10+',
#      'developers': "['iNiS']",
#      'genres': "['Action', 'Miscellaneous', 'Rhythm', 'Music', 'Music']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'ADq4XIoBTw-2vdEqo5LK',
#     '_score': 10.955938,
#     '_source': {'meta_score': None,
#      'title': "America's Test Kitchen: Let's Get Cooking",
#      'platform': 'WII',
#      'date': 'Mar 28, 2010',
#      'user_score': None,
#      'link': '/game/wii/americas-test-kitchen-lets-get-cooking',
#      'esrb_rating': None,
#      'developers': None,
#      'genres': "['Miscellaneous', 'General']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'ATq4XIoBTw-2vdEqo5LK',
#     '_score': 10.955938,
#     '_source': {'meta_score': 87.0,
#      'title': "America's Test Kitchen: Let's Get Cooking",
#      'platform': 'DS',
#      'date': 'Mar 28, 2010',
#      'user_score': 6.3,
#      'link': '/game/ds/americas-test-kitchen-lets-get-cooking',
#      'esrb_rating': 'E',
#      'developers': "['indieszero']",
#      'genres': "['Miscellaneous', 'General', 'General']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'SjrCXIoBTw-2vdEq9Jah',
#     '_score': 10.955938,
#     '_source': {'meta_score': None,
#      'title': "America's Test Kitchen: Let's Get Cooking",
#      'platform': 'WII',
#      'date': 'Mar 28, 2010',
#      'user_score': None,
#      'link': '/game/wii/americas-test-kitchen-lets-get-cooking',
#      'esrb_rating': None,
#      'developers': None,
#      'genres': "['Miscellaneous', 'General']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'SzrCXIoBTw-2vdEq9Jah',
#     '_score': 10.955938,
#     '_source': {'meta_score': 87.0,
#      'title': "America's Test Kitchen: Let's Get Cooking",
#      'platform': 'DS',
#      'date': 'Mar 28, 2010',
#      'user_score': 6.3,
#      'link': '/game/ds/americas-test-kitchen-lets-get-cooking',
#      'esrb_rating': 'E',
#      'developers': "['indieszero']",
#      'genres': "['Miscellaneous', 'General', 'General']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'Mzq4XIoBTw-2vdEqo5PL',
#     '_score': 8.051357,
#     '_source': {'meta_score': 66.0,
#      'title': 'Geist',
#      'platform': 'GC',
#      'date': 'Aug 15, 2005',
#      'user_score': 8.0,
#      'link': '/game/gamecube/geist',
#      'esrb_rating': 'M',
#      'developers': "['n-Space']",
#      'genres': "['Action', 'Shooter', 'First-Person', 'Sci-Fi']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'fTrCXIoBTw-2vdEq9Jeh',
#     '_score': 8.051357,
#     '_source': {'meta_score': 66.0,
#      'title': 'Geist',
#      'platform': 'GC',
#      'date': 'Aug 15, 2005',
#      'user_score': 8.0,
#      'link': '/game/gamecube/geist',
#      'esrb_rating': 'M',
#      'developers': "['n-Space']",
#      'genres': "['Action', 'Shooter', 'First-Person', 'Sci-Fi']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'wTq4XIoBTw-2vdEqo4_K',
#     '_score': 7.513192,
#     '_source': {'meta_score': 76.0,
#      'title': 'WarioWare: Get It Together!',
#      'platform': 'Switch',
#      'date': 'Sep 10, 2021',
#      'user_score': 7.7,
#      'link': '/game/switch/warioware-get-it-together!',
#      'esrb_rating': 'E10+',
#      'developers': "['Nintendo', ' Intelligent Systems']",
#      'genres': "['Miscellaneous', 'Party / Minigame']"}},
#    {'_index': 'nintendo_games',
#     '_id': 'CzrCXIoBTw-2vdEq9JSg',
#     '_score': 7.513192,
#     '_source': {'meta_score': 76.0,
#      'title': 'WarioWare: Get It Together!',
#      'platform': 'Switch',
#      'date': 'Sep 10, 2021',
#      'user_score': 7.7,
#      'link': '/game/switch/warioware-get-it-together!',
#      'esrb_rating': 'E10+',
#      'developers': "['Nintendo', ' Intelligent Systems']",
#      'genres': "['Miscellaneous', 'Party / Minigame']"}}]}}

# %% [markdown]
# Term Search

# %%
genres_mapping = index_mapping['nintendo_games']['mappings']['properties']['genres']

# %%
genres_mapping
# Out:
# {'type': 'keyword'}

# %%
search_4 = opensearch_client.search(body={
    "query": {
        "term": {
            "genres":{
                "value": "Miscellaneous",
                 "case_insensitive": True
            }
        }
    }
})

# %%
search_4
# Out:
# {'took': 29,
#  'timed_out': False,
#  '_shards': {'total': 6, 'successful': 6, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 291, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'nintendo_games',
#     '_id': 'HjoyXYoBTw-2vdEqh5jC',
#     '_score': 1.0,
#     '_source': {'meta_score': None,
#      'title': 'WarioWare: Move It!',
#      'platform': 'Switch',
#      'date': 'Nov 3, 2023',
#      'user_score': None,
#      'link': '/game/switch/warioware-move-it!',
#      'esrb_rating': 'RP',
#      'developers': "['Intelligent Systems']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'IzoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': None,
#      'title': 'Pokemon Sleep',
#      'platform': 'iOS',
#      'date': 'Jul 20, 2023',
#      'user_score': None,
#      'link': '/game/ios/pokemon-sleep',
#      'esrb_rating': None,
#      'developers': "['The Pokemon Company', ' Select Button']",
#      'genres': ['Role-Playing', 'Miscellaneous', 'Application', 'Trainer']}},
#    {'_index': 'nintendo_games',
#     '_id': 'JToyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 56.0,
#      'title': 'Everybody 1-2-Switch!',
#      'platform': 'Switch',
#      'date': 'Jun 30, 2023',
#      'user_score': 5.4,
#      'link': '/game/switch/everybody-1-2-switch!',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'KDoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 80.0,
#      'title': 'Pikmin 1 + 2',
#      'platform': 'Switch',
#      'date': 'Jun 21, 2023',
#      'user_score': 8.5,
#      'link': '/game/switch/pikmin-1-+-2',
#      'esrb_rating': None,
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'Compilation']}},
#    {'_index': 'nintendo_games',
#     '_id': 'OjoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': None,
#      'title': 'Pokemon Scarlet / Pokemon Violet Dual Pack Steelbook Edition',
#      'platform': 'Switch',
#      'date': 'Nov 18, 2022',
#      'user_score': 8.0,
#      'link': '/game/switch/pokemon-scarlet-pokemon-violet-dual-pack-steelbook-edition',
#      'esrb_rating': 'RP',
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'Compilation', 'Role-Playing', 'Trainer']}},
#    {'_index': 'nintendo_games',
#     '_id': 'PjoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 67.0,
#      'title': "Kirby's Dream Buffet",
#      'platform': 'Switch',
#      'date': 'Aug 17, 2022',
#      'user_score': 7.3,
#      'link': '/game/switch/kirbys-dream-buffet',
#      'esrb_rating': 'E',
#      'developers': "['HAL Labs']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'SDoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 73.0,
#      'title': 'Big Brain Academy: Brain vs. Brain',
#      'platform': 'Switch',
#      'date': 'Dec 3, 2021',
#      'user_score': 8.1,
#      'link': '/game/switch/big-brain-academy-brain-vs-brain',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'TjoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 80.0,
#      'title': 'Mario Party Superstars',
#      'platform': 'Switch',
#      'date': 'Oct 29, 2021',
#      'user_score': 8.0,
#      'link': '/game/switch/mario-party-superstars',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo', ' Nd Cube']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'VDoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 76.0,
#      'title': 'WarioWare: Get It Together!',
#      'platform': 'Switch',
#      'date': 'Sep 10, 2021',
#      'user_score': 7.7,
#      'link': '/game/switch/warioware-get-it-together!',
#      'esrb_rating': 'E10+',
#      'developers': "['Nintendo', ' Intelligent Systems']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'VjoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': None,
#      'title': 'Fitness Boxing 2: Rhythm & Exercise - Musical Journey',
#      'platform': 'Switch',
#      'date': 'Jul 1, 2021',
#      'user_score': None,
#      'link': '/game/switch/fitness-boxing-2-rhythm-exercise---musical-journey',
#      'esrb_rating': None,
#      'developers': "['Jupiter Corporation']",
#      'genres': ['Miscellaneous', 'Exercise / Fitness']}}]}}

# %%
search_5 = opensearch_client.search(body={
    "query": {
        "wildcard": {
            "genres":{
                "value": "Miscell*",
                 "case_insensitive": False
            }
        }
    }
})

# %%
search_5
# Out:
# {'took': 13,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 291, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'nintendo_games',
#     '_id': 'HjoyXYoBTw-2vdEqh5jC',
#     '_score': 1.0,
#     '_source': {'meta_score': None,
#      'title': 'WarioWare: Move It!',
#      'platform': 'Switch',
#      'date': 'Nov 3, 2023',
#      'user_score': None,
#      'link': '/game/switch/warioware-move-it!',
#      'esrb_rating': 'RP',
#      'developers': "['Intelligent Systems']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'IzoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': None,
#      'title': 'Pokemon Sleep',
#      'platform': 'iOS',
#      'date': 'Jul 20, 2023',
#      'user_score': None,
#      'link': '/game/ios/pokemon-sleep',
#      'esrb_rating': None,
#      'developers': "['The Pokemon Company', ' Select Button']",
#      'genres': ['Role-Playing', 'Miscellaneous', 'Application', 'Trainer']}},
#    {'_index': 'nintendo_games',
#     '_id': 'JToyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 56.0,
#      'title': 'Everybody 1-2-Switch!',
#      'platform': 'Switch',
#      'date': 'Jun 30, 2023',
#      'user_score': 5.4,
#      'link': '/game/switch/everybody-1-2-switch!',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'KDoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 80.0,
#      'title': 'Pikmin 1 + 2',
#      'platform': 'Switch',
#      'date': 'Jun 21, 2023',
#      'user_score': 8.5,
#      'link': '/game/switch/pikmin-1-+-2',
#      'esrb_rating': None,
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'Compilation']}},
#    {'_index': 'nintendo_games',
#     '_id': 'OjoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': None,
#      'title': 'Pokemon Scarlet / Pokemon Violet Dual Pack Steelbook Edition',
#      'platform': 'Switch',
#      'date': 'Nov 18, 2022',
#      'user_score': 8.0,
#      'link': '/game/switch/pokemon-scarlet-pokemon-violet-dual-pack-steelbook-edition',
#      'esrb_rating': 'RP',
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'Compilation', 'Role-Playing', 'Trainer']}},
#    {'_index': 'nintendo_games',
#     '_id': 'PjoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 67.0,
#      'title': "Kirby's Dream Buffet",
#      'platform': 'Switch',
#      'date': 'Aug 17, 2022',
#      'user_score': 7.3,
#      'link': '/game/switch/kirbys-dream-buffet',
#      'esrb_rating': 'E',
#      'developers': "['HAL Labs']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'SDoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 73.0,
#      'title': 'Big Brain Academy: Brain vs. Brain',
#      'platform': 'Switch',
#      'date': 'Dec 3, 2021',
#      'user_score': 8.1,
#      'link': '/game/switch/big-brain-academy-brain-vs-brain',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'TjoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 80.0,
#      'title': 'Mario Party Superstars',
#      'platform': 'Switch',
#      'date': 'Oct 29, 2021',
#      'user_score': 8.0,
#      'link': '/game/switch/mario-party-superstars',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo', ' Nd Cube']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'VDoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': 76.0,
#      'title': 'WarioWare: Get It Together!',
#      'platform': 'Switch',
#      'date': 'Sep 10, 2021',
#      'user_score': 7.7,
#      'link': '/game/switch/warioware-get-it-together!',
#      'esrb_rating': 'E10+',
#      'developers': "['Nintendo', ' Intelligent Systems']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'VjoyXYoBTw-2vdEqh5jD',
#     '_score': 1.0,
#     '_source': {'meta_score': None,
#      'title': 'Fitness Boxing 2: Rhythm & Exercise - Musical Journey',
#      'platform': 'Switch',
#      'date': 'Jul 1, 2021',
#      'user_score': None,
#      'link': '/game/switch/fitness-boxing-2-rhythm-exercise---musical-journey',
#      'esrb_rating': None,
#      'developers': "['Jupiter Corporation']",
#      'genres': ['Miscellaneous', 'Exercise / Fitness']}}]}}

# %% [markdown]
# Compound queries

# %%
search_6 = opensearch_client.search(body={
    "query": {
        "bool": {
            "must": [
                {
                    "match": {
                        "title": "Mario"
                    }
                },
                ],
            "must_not": [
                {
                    "match": {
                        "genres": "Miscellaneous"
                    }
                }
            ]
        }
    }
})

# %%
search_6
# Out:
# {'took': 44,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 120, 'relation': 'eq'},
#   'max_score': 2.509985,
#   'hits': [{'_index': 'nintendo_games',
#     '_id': 'dzoyXYoBTw-2vdEqh5rE',
#     '_score': 2.509985,
#     '_source': {'meta_score': None,
#      'title': 'Mario Tennis',
#      'platform': 'WII',
#      'date': 'Jun 28, 2010',
#      'user_score': None,
#      'link': '/game/wii/mario-tennis',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': ['Sports', 'Traditional', 'Tennis']}},
#    {'_index': 'nintendo_games',
#     '_id': 'CDoyXYoBTw-2vdEqh5vE',
#     '_score': 2.509985,
#     '_source': {'meta_score': None,
#      'title': 'Mario Golf',
#      'platform': 'WII',
#      'date': 'Oct 6, 2008',
#      'user_score': None,
#      'link': '/game/wii/mario-golf',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': ['Sports', 'Traditional', 'Golf', 'Arcade']}},
#    {'_index': 'nintendo_games',
#     '_id': 'RjoyXYoBTw-2vdEqh5vE',
#     '_score': 2.509985,
#     '_source': {'meta_score': None,
#      'title': 'Paper Mario',
#      'platform': 'WII',
#      'date': 'Jul 16, 2007',
#      'user_score': 8.7,
#      'link': '/game/wii/paper-mario',
#      'esrb_rating': 'E',
#      'developers': "['Intelligent Systems']",
#      'genres': ['Role-Playing', 'Console-style RPG']}},
#    {'_index': 'nintendo_games',
#     '_id': 'jDoyXYoBTw-2vdEqh5vE',
#     '_score': 2.509985,
#     '_source': {'meta_score': None,
#      'title': 'Mario Bros.',
#      'platform': 'WII',
#      'date': 'Nov 19, 2006',
#      'user_score': 6.6,
#      'link': '/game/wii/mario-bros',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Action', 'Platformer', '2D']}},
#    {'_index': 'nintendo_games',
#     '_id': 'MToyXYoBTw-2vdEqh5zE',
#     '_score': 2.509985,
#     '_source': {'meta_score': 93.0,
#      'title': 'Paper Mario',
#      'platform': 'N64',
#      'date': 'Feb 5, 2001',
#      'user_score': 9.0,
#      'link': '/game/nintendo-64/paper-mario',
#      'esrb_rating': 'E',
#      'developers': "['Intelligent Systems']",
#      'genres': ['Role-Playing', 'Console-style RPG']}},
#    {'_index': 'nintendo_games',
#     '_id': 'NzoyXYoBTw-2vdEqh5zE',
#     '_score': 2.509985,
#     '_source': {'meta_score': 91.0,
#      'title': 'Mario Tennis',
#      'platform': 'N64',
#      'date': 'Aug 28, 2000',
#      'user_score': 8.7,
#      'link': '/game/nintendo-64/mario-tennis',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': ['Sports', 'Traditional', 'Tennis']}},
#    {'_index': 'nintendo_games',
#     '_id': 'PToyXYoBTw-2vdEqh5zE',
#     '_score': 2.509985,
#     '_source': {'meta_score': 91.0,
#      'title': 'Mario Golf',
#      'platform': 'N64',
#      'date': 'Jun 30, 1999',
#      'user_score': 7.8,
#      'link': '/game/nintendo-64/mario-golf',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': ['Sports', 'Traditional', 'Golf', 'Arcade']}},
#    {'_index': 'nintendo_games',
#     '_id': 'IjoyXYoBTw-2vdEqh5zE',
#     '_score': 2.279567,
#     '_source': {'meta_score': 92.0,
#      'title': 'Super Mario World: Super Mario Advance 2',
#      'platform': 'GBA',
#      'date': 'Feb 9, 2002',
#      'user_score': 9.1,
#      'link': '/game/game-boy-advance/super-mario-world-super-mario-advance-2',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Action', 'Platformer', '2D']}},
#    {'_index': 'nintendo_games',
#     '_id': 'HToyXYoBTw-2vdEqh5jC',
#     '_score': 2.2309625,
#     '_source': {'meta_score': None,
#      'title': 'Super Mario RPG',
#      'platform': 'Switch',
#      'date': 'Nov 17, 2023',
#      'user_score': None,
#      'link': '/game/switch/super-mario-rpg',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Role-Playing', 'Japanese-Style']}},
#    {'_index': 'nintendo_games',
#     '_id': 'ljoyXYoBTw-2vdEqh5jD',
#     '_score': 2.2309625,
#     '_source': {'meta_score': 59.0,
#      'title': 'Mario Kart Tour',
#      'platform': 'iOS',
#      'date': 'Sep 25, 2019',
#      'user_score': 4.2,
#      'link': '/game/ios/mario-kart-tour',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Racing', 'Arcade', 'Automobile']}}]}}

# %%
search_7 = opensearch_client.search(body={
    "query": {
        "bool": {
            "must": [
                {
                    "match": {
                        "title": "Mario"
                    }
                },
                {
                    "match": {
                        "genres": "Miscellaneous"
                    }
                }
            ]
        }
    }
})

# %%
search_7
# Out:
# {'took': 16,
#  'timed_out': False,
#  '_shards': {'total': 6, 'successful': 6, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 31, 'relation': 'eq'},
#   'max_score': 4.335801,
#   'hits': [{'_index': 'nintendo_games',
#     '_id': '3DoyXYoBTw-2vdEqh5rE',
#     '_score': 4.335801,
#     '_source': {'meta_score': None,
#      'title': 'Mario Calculator',
#      'platform': 'DS',
#      'date': 'Jun 15, 2009',
#      'user_score': 6.3,
#      'link': '/game/ds/mario-calculator',
#      'esrb_rating': None,
#      'developers': "['Nintendo']",
#      'genres': ['Action', 'Miscellaneous', 'General', 'Edutainment']}},
#    {'_index': 'nintendo_games',
#     '_id': '3ToyXYoBTw-2vdEqh5rE',
#     '_score': 4.335801,
#     '_source': {'meta_score': None,
#      'title': 'Mario Clock',
#      'platform': 'DS',
#      'date': 'Jun 15, 2009',
#      'user_score': 6.0,
#      'link': '/game/ds/mario-clock',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'General', 'General', 'Application']}},
#    {'_index': 'nintendo_games',
#     '_id': 'QDoyXYoBTw-2vdEqh5zE',
#     '_score': 4.335801,
#     '_source': {'meta_score': 79.0,
#      'title': 'Mario Party',
#      'platform': 'N64',
#      'date': 'Feb 8, 1999',
#      'user_score': 8.0,
#      'link': '/game/nintendo-64/mario-party',
#      'esrb_rating': 'E',
#      'developers': "['Hudson']",
#      'genres': ['Miscellaneous', 'Party']}},
#    {'_index': 'nintendo_games',
#     '_id': 'bzoyXYoBTw-2vdEqh5jD',
#     '_score': 4.1053834,
#     '_source': {'meta_score': None,
#      'title': 'Mario Kart 8 Deluxe + Super Mario Party',
#      'platform': 'Switch',
#      'date': 'Oct 4, 2020',
#      'user_score': None,
#      'link': '/game/switch/mario-kart-8-deluxe-+-super-mario-party',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'Compilation']}},
#    {'_index': 'nintendo_games',
#     '_id': 'TjoyXYoBTw-2vdEqh5jD',
#     '_score': 4.056779,
#     '_source': {'meta_score': 80.0,
#      'title': 'Mario Party Superstars',
#      'platform': 'Switch',
#      'date': 'Oct 29, 2021',
#      'user_score': 8.0,
#      'link': '/game/switch/mario-party-superstars',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo', ' Nd Cube']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'ujoyXYoBTw-2vdEqh5jD',
#     '_score': 4.056779,
#     '_source': {'meta_score': 76.0,
#      'title': 'Super Mario Party',
#      'platform': 'Switch',
#      'date': 'Oct 5, 2018',
#      'user_score': 7.0,
#      'link': '/game/switch/super-mario-party',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo', ' Nd Cube']",
#      'genres': ['Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'gjoyXYoBTw-2vdEqh5nD',
#     '_score': 4.056779,
#     '_source': {'meta_score': 66.0,
#      'title': 'Mario Party 10',
#      'platform': 'WIIU',
#      'date': 'Mar 20, 2015',
#      'user_score': 6.4,
#      'link': '/game/wii-u/mario-party-10',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo', ' Nd Cube']",
#      'genres': ['Party', 'Miscellaneous', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'pzoyXYoBTw-2vdEqh5nD',
#     '_score': 4.056779,
#     '_source': {'meta_score': None,
#      'title': 'Photos with Mario',
#      'platform': '3DS',
#      'date': 'May 18, 2014',
#      'user_score': 6.9,
#      'link': '/game/3ds/photos-with-mario',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'General']}},
#    {'_index': 'nintendo_games',
#     '_id': 'KjoyXYoBTw-2vdEqh5rD',
#     '_score': 4.056779,
#     '_source': {'meta_score': 73.0,
#      'title': 'Mario Party 9',
#      'platform': 'WII',
#      'date': 'Mar 11, 2012',
#      'user_score': 6.8,
#      'link': '/game/wii/mario-party-9',
#      'esrb_rating': 'E',
#      'developers': "['Nd Cube']",
#      'genres': ['Miscellaneous', 'Party', 'Party', 'Party / Minigame']}},
#    {'_index': 'nintendo_games',
#     '_id': 'YToyXYoBTw-2vdEqh5rE',
#     '_score': 4.056779,
#     '_source': {'meta_score': None,
#      'title': 'Mario Party 2',
#      'platform': 'WII',
#      'date': 'Dec 20, 2010',
#      'user_score': 8.6,
#      'link': '/game/wii/mario-party-2',
#      'esrb_rating': None,
#      'developers': "['Hudson']",
#      'genres': ['Miscellaneous', 'Party']}}]}}

# %%
search_8 = opensearch_client.search(body={
  "query": {
    "match": {
      "text_entry": {
        "query": "Mario Party", 
        "minimum_should_match": "2"
      }
    }
  }
})

# %%
search_8
# Out:
# {'took': 5,
#  'timed_out': False,
#  '_shards': {'total': 6, 'successful': 6, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}

# %%
search_9 = opensearch_client.search(body={
  "query": {
    "match_phrase_prefix": {
      "text_entry": {
        "query": "Mari",
        "slop": 3
      }
    }
  }
})

# %%
search_9
# Out:
# {'took': 9,
#  'timed_out': False,
#  '_shards': {'total': 6, 'successful': 6, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}

# %%
search_10 = opensearch_client.search(body={
    "query": {
        "match": {
            "title": "Mario"
        }
    }
})

# %%
search_10
# Out:
# {'took': 15,
#  'timed_out': False,
#  '_shards': {'total': 6, 'successful': 6, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 151, 'relation': 'eq'},
#   'max_score': 2.509985,
#   'hits': [{'_index': 'nintendo_games',
#     '_id': 'dzoyXYoBTw-2vdEqh5rE',
#     '_score': 2.509985,
#     '_source': {'meta_score': None,
#      'title': 'Mario Tennis',
#      'platform': 'WII',
#      'date': 'Jun 28, 2010',
#      'user_score': None,
#      'link': '/game/wii/mario-tennis',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': ['Sports', 'Traditional', 'Tennis']}},
#    {'_index': 'nintendo_games',
#     '_id': '3DoyXYoBTw-2vdEqh5rE',
#     '_score': 2.509985,
#     '_source': {'meta_score': None,
#      'title': 'Mario Calculator',
#      'platform': 'DS',
#      'date': 'Jun 15, 2009',
#      'user_score': 6.3,
#      'link': '/game/ds/mario-calculator',
#      'esrb_rating': None,
#      'developers': "['Nintendo']",
#      'genres': ['Action', 'Miscellaneous', 'General', 'Edutainment']}},
#    {'_index': 'nintendo_games',
#     '_id': '3ToyXYoBTw-2vdEqh5rE',
#     '_score': 2.509985,
#     '_source': {'meta_score': None,
#      'title': 'Mario Clock',
#      'platform': 'DS',
#      'date': 'Jun 15, 2009',
#      'user_score': 6.0,
#      'link': '/game/ds/mario-clock',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Miscellaneous', 'General', 'General', 'Application']}},
#    {'_index': 'nintendo_games',
#     '_id': 'CDoyXYoBTw-2vdEqh5vE',
#     '_score': 2.509985,
#     '_source': {'meta_score': None,
#      'title': 'Mario Golf',
#      'platform': 'WII',
#      'date': 'Oct 6, 2008',
#      'user_score': None,
#      'link': '/game/wii/mario-golf',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': ['Sports', 'Traditional', 'Golf', 'Arcade']}},
#    {'_index': 'nintendo_games',
#     '_id': 'RjoyXYoBTw-2vdEqh5vE',
#     '_score': 2.509985,
#     '_source': {'meta_score': None,
#      'title': 'Paper Mario',
#      'platform': 'WII',
#      'date': 'Jul 16, 2007',
#      'user_score': 8.7,
#      'link': '/game/wii/paper-mario',
#      'esrb_rating': 'E',
#      'developers': "['Intelligent Systems']",
#      'genres': ['Role-Playing', 'Console-style RPG']}},
#    {'_index': 'nintendo_games',
#     '_id': 'jDoyXYoBTw-2vdEqh5vE',
#     '_score': 2.509985,
#     '_source': {'meta_score': None,
#      'title': 'Mario Bros.',
#      'platform': 'WII',
#      'date': 'Nov 19, 2006',
#      'user_score': 6.6,
#      'link': '/game/wii/mario-bros',
#      'esrb_rating': 'E',
#      'developers': "['Nintendo']",
#      'genres': ['Action', 'Platformer', '2D']}},
#    {'_index': 'nintendo_games',
#     '_id': 'MToyXYoBTw-2vdEqh5zE',
#     '_score': 2.509985,
#     '_source': {'meta_score': 93.0,
#      'title': 'Paper Mario',
#      'platform': 'N64',
#      'date': 'Feb 5, 2001',
#      'user_score': 9.0,
#      'link': '/game/nintendo-64/paper-mario',
#      'esrb_rating': 'E',
#      'developers': "['Intelligent Systems']",
#      'genres': ['Role-Playing', 'Console-style RPG']}},
#    {'_index': 'nintendo_games',
#     '_id': 'NzoyXYoBTw-2vdEqh5zE',
#     '_score': 2.509985,
#     '_source': {'meta_score': 91.0,
#      'title': 'Mario Tennis',
#      'platform': 'N64',
#      'date': 'Aug 28, 2000',
#      'user_score': 8.7,
#      'link': '/game/nintendo-64/mario-tennis',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': ['Sports', 'Traditional', 'Tennis']}},
#    {'_index': 'nintendo_games',
#     '_id': 'PToyXYoBTw-2vdEqh5zE',
#     '_score': 2.509985,
#     '_source': {'meta_score': 91.0,
#      'title': 'Mario Golf',
#      'platform': 'N64',
#      'date': 'Jun 30, 1999',
#      'user_score': 7.8,
#      'link': '/game/nintendo-64/mario-golf',
#      'esrb_rating': 'E',
#      'developers': "['Camelot Software Planning']",
#      'genres': ['Sports', 'Traditional', 'Golf', 'Arcade']}},
#    {'_index': 'nintendo_games',
#     '_id': 'QDoyXYoBTw-2vdEqh5zE',
#     '_score': 2.509985,
#     '_source': {'meta_score': 79.0,
#      'title': 'Mario Party',
#      'platform': 'N64',
#      'date': 'Feb 8, 1999',
#      'user_score': 8.0,
#      'link': '/game/nintendo-64/mario-party',
#      'esrb_rating': 'E',
#      'developers': "['Hudson']",
#      'genres': ['Miscellaneous', 'Party']}}]}}
